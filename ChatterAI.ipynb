# %%
#@title Chatter AI
#@markdown Please input your [HuggingFace Token](https://huggingface.co/settings/tokens):
hf_token = "" #@param {type: "string"}
# !pip install -U chatter-ai-7b
from chatter_ai import AI
AI.set_api_token(hf_token)

# %%
#@markdown Please input your question:
question= "What you're name?" #@param {type: "string"}
#@markdown and run.
#@markdown
#@markdown If the AI ​​writes your response, put it here True:
is_bad = False #@param
if is_bad:
 AI.take_damage_prompt()
print(AI.get_answer(question))
